# %%
class month_data():
    def __init__(self):
        print("INIT")
        self.data = False

    def set_data(self):
        self.data = True


febbraio2022 = month_data()
print(febbraio2022.data)
febbraio2022.set_data()
print(febbraio2022.data)
# Out:
# INIT
# False
# True

# %%
import pandas as pd

df_data = pd.read_excel("DATI.xlsx", sheet_name="DATI")

df_data
# Out:
#      Data Lettura Data reale Giorno  Dato Fascia 1  Consumi GAS [Smc]  \
# 0      2021-03-19 2021-03-18    GIO        3565794               3132
# 1      2021-03-18 2021-03-17    MER        3562662               3060
# 2      2021-03-17 2021-03-16    MAR        3559602               3024
# 3      2021-03-16 2021-03-15    LUN        3556578               3070
# 4      2021-03-15 2021-03-14    DOM        3553508               3038
# ...           ...        ...    ...            ...                ...
# 1534   2017-01-05 2017-01-04    MER        1894407               2579
# 1535   2017-01-04 2017-01-03    MAR        1891828               2493
# 1536   2017-01-03 2017-01-02    LUN        1889335               2728
# 1537   2017-01-02 2017-01-01    DOM        1886607               2696
# 1538   2017-01-01 2016-12-31    SAB        1883911                  0
#
#       Consumi ELETTRICI [kwh]  Consumi in TEP  Schema Cogen  \
# 0                         0.0             0.0          12.0
# ...
